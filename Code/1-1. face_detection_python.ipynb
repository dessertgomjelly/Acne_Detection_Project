# %%
from mtcnn.mtcnn import MTCNN
import cv2
import matplotlib.pyplot as plt

image_path = 'image3.png'  # 이미지 파일 경로를 적절히 수정해주세요.
img = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)

detector = MTCNN()
detections = detector.detect_faces(img)

min_conf = 0.9
for i, det in enumerate(detections):
    if det['confidence'] >= min_conf:
        x, y, width, height = det['box']
        keypoints = det['keypoints']
        cropped_face = img[y:y+height, x:x+width]  # 얼굴 부분 crop
        cv2.rectangle(img, (x, y), (x + width, y + height), (0, 155, 255), 2)

        # crop된 얼굴 이미지 저장
        cv2.imwrite(f'cropped_face_{i}.png', cv2.cvtColor(cropped_face, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.axis('off')
# Out:
# ...
# 1/1 [==============================] - 0s 70ms/step
# (-0.5, 272.5, 307.5, -0.5)
